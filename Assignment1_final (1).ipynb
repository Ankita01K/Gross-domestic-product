# %% [markdown]
# # 1-Importing the Libraries:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from statistics import mode
from statistics import mean
import matplotlib.pyplot as plt
from statistics import median
import math
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 2-Importing the dataset

# %%
df=pd.read_csv("/content/gdp1.csv",decimal=',')
df
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...

# %% [markdown]
# #### Checking First 10 Rows

# %%
df.head(10)
# Out:
#               Country                               Region  Population  \
# 0        Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1            Albania   EASTERN EUROPE                          3581655
# 2            Algeria   NORTHERN AFRICA                        32930091
# 3     American Samoa   OCEANIA                                   57794
# 4            Andorra   WESTERN EUROPE                            71201
# 5             Angola   SUB-SAHARAN AFRICA                     12127071
# 6           Anguilla               LATIN AMER. & CARIB           13477
# 7  Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8          Argentina               LATIN AMER. & CARIB        39921833
# 9            Armenia                  C.W. OF IND. STATES      2976372
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# ...

# %% [markdown]
# ### Shape of the dataset

# %%
df.shape
# Out:
# (227, 20)

# %% [markdown]
# ## 2-Data Cleansing

# %% [markdown]
# ### Checking the datatypes

# %%
df.dtypes
# Out:
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)            float64
# Coastline (coast/area ratio)          float64
# Net migration                         float64
# Infant mortality (per 1000 births)    float64
# GDP ($ per capita)                    float64
# Literacy (%)                          float64
# Phones (per 1000)                     float64
# Arable (%)                            float64
# Crops (%)                             float64
# Other (%)                             float64
# Climate                               float64
# Birthrate                             float64
# Deathrate                             float64
# Agriculture                           float64
# Industry                              float64
# Service                               float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    float64
#  5   Coastline (coast/area ratio)        227 non-null    float64
#  6   Net migration                       224 non-null    float64
#  7   Infant mortality (per 1000 births)  224 non-null    float64
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    float64
#  10  Phones (per 1000)                   223 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
df["Literacy (%)"].mean()
# Out:
# 82.83827751196175

# %%
values = {
           "Literacy (%)" : df["Literacy (%)"].mean(),
           "Climate" : df["Climate"].mean(),
           "Agriculture" : df["Agriculture"].mean(),
           "Industry" : df["Industry"].mean(),
           "Service" : df["Service"].mean()
        }

# %%
df.fillna(values,inplace=True)

# %%
df.isnull().sum()
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         3
# Infant mortality (per 1000 births)    3
# GDP ($ per capita)                    1
# Literacy (%)                          0
# Phones (per 1000)                     4
# Arable (%)                            2
# Crops (%)                             2
# Other (%)                             2
# Climate                               0
# Birthrate                             3
# Deathrate                             4
# Agriculture                           0
# Industry                              0
# Service                               0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         0
# Infant mortality (per 1000 births)    0
# GDP ($ per capita)                    0
# Literacy (%)                          0
# Phones (per 1000)                     0
# Arable (%)                            0
# Crops (%)                             0
# Other (%)                             0
# Climate                               0
# Birthrate                             0
# Deathrate                             0
# Agriculture                           0
# Industry                              0
# Service                               0
# dtype: int64

# %%
df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %% [markdown]
# ## Data Analysis

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'Population', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['Population'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['Population'],25),np.percentile(df['Population'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['Population'] if i < lower or i > upper]
print('{} Total Number of outliers in Population: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-18-28d4f4b62ebb>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Population'],  ax=axes[0])
#  Total Number of outliers in Population: 26

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'Area (sq. mi.)', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['Area (sq. mi.)'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['Area (sq. mi.)'],25),np.percentile(df['Area (sq. mi.)'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['Area (sq. mi.)'] if i < lower or i > upper]
print('{} Total Number of outliers in Area: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-19-8de409e07503>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Area (sq. mi.)'],  ax=axes[0])
#  Total Number of outliers in Area: 27

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'Pop. Density (per sq. mi.)', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['Pop. Density (per sq. mi.)'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['Pop. Density (per sq. mi.)'],25),np.percentile(df['Pop. Density (per sq. mi.)'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['Pop. Density (per sq. mi.)'] if i < lower or i > upper]
print('{} Total Number of outliers in Pop_Density: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-20-ccadcf11b090>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Pop. Density (per sq. mi.)'],  ax=axes[0])
#  Total Number of outliers in Pop_Density: 19

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'Coastline (coast/area ratio)', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['Coastline (coast/area ratio)'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['Coastline (coast/area ratio)'],25),np.percentile(df['Coastline (coast/area ratio)'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['Coastline (coast/area ratio)'] if i < lower or i > upper]
print('{} Total Number of outliers in Coastline: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-21-cae2d7cd6f0d>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Coastline (coast/area ratio)'],  ax=axes[0])
#  Total Number of outliers in Coastline: 37

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'Net migration', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['Net migration'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['Net migration'],25),np.percentile(df['Net migration'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['Net migration'] if i < lower or i > upper]
print('{} Total Number of outliers in Net_migration: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-22-2aa32c95d34a>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Net migration'],  ax=axes[0])
#  Total Number of outliers in Net_migration: 49

# %%
#for i in df.columns:
 # sns.distplot(df[i])
  #plt.title(i)

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'GDP ($ per capita)', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['GDP ($ per capita)'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['GDP ($ per capita)'],25),np.percentile(df['GDP ($ per capita)'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['GDP ($ per capita)'] if i < lower or i > upper]
print('{} Total Number of outliers in GDP: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-24-8262bb866034>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['GDP ($ per capita)'],  ax=axes[0])
#  Total Number of outliers in GDP: 3

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'Infant mortality (per 1000 births)', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['Infant mortality (per 1000 births)'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['Infant mortality (per 1000 births)'],25),np.percentile(df['Infant mortality (per 1000 births)'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['Infant mortality (per 1000 births)'] if i < lower or i > upper]
print('{} Total Number of outliers in Infant_mortality: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-25-a3e23543e161>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Infant mortality (per 1000 births)'],  ax=axes[0])
#  Total Number of outliers in Infant_mortality: 5

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'Literacy (%)', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['Literacy (%)'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['Literacy (%)'],25),np.percentile(df['Literacy (%)'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['Literacy (%)'] if i < lower or i > upper]
print('{} Total Number of outliers in Literacy: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-26-abe8315a8ace>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Literacy (%)'],  ax=axes[0])
#  Total Number of outliers in Literacy: 16

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'Phones (per 1000)', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['Phones (per 1000)'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['Phones (per 1000)'],25),np.percentile(df['Phones (per 1000)'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['Phones (per 1000)'] if i < lower or i > upper]
print('{} Total Number of outliers in Phones: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-27-7a360a6a9f42>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Phones (per 1000)'],  ax=axes[0])
#  Total Number of outliers in Phones: 1

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'Arable (%)', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['Arable (%)'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['Arable (%)'],25),np.percentile(df['Arable (%)'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['Arable (%)'] if i < lower or i > upper]
print('{} Total Number of outliers in Arable: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-29-f4ea3cac75d3>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Arable (%)'],  ax=axes[0])
#  Total Number of outliers in Arable: 9

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'Crops (%)', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['Crops (%)'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['Crops (%)'],25),np.percentile(df['Crops (%)'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['Crops (%)'] if i < lower or i > upper]
print('{} Total Number of outliers in Crops: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-30-462cabbaec10>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Crops (%)'],  ax=axes[0])
#  Total Number of outliers in Crops: 28

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'Other (%)', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['Other (%)'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['Other (%)'],25),np.percentile(df['Other (%)'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['Other (%)'] if i < lower or i > upper]
print('{} Total Number of outliers in Other: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-31-a35c5dd5a433>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Other (%)'],  ax=axes[0])
#  Total Number of outliers in Other: 3

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'Climate', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['Climate'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['Climate'],25),np.percentile(df['Climate'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['Climate'] if i < lower or i > upper]
print('{} Total Number of outliers in Climate: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-32-215b24c5cb38>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Climate'],  ax=axes[0])
#  Total Number of outliers in Climate: 34

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'Birthrate', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['Birthrate'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['Birthrate'],25),np.percentile(df['Birthrate'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['Birthrate'] if i < lower or i > upper]
print('{} Total Number of outliers in Birthrate: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-33-b0d5487283e9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Birthrate'],  ax=axes[0])
#  Total Number of outliers in Birthrate: 0

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'Deathrate', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['Deathrate'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['Deathrate'],25),np.percentile(df['Deathrate'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['Deathrate'] if i < lower or i > upper]
print('{} Total Number of outliers in Deathrate: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-34-14230dfc5a79>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Deathrate'],  ax=axes[0])
#  Total Number of outliers in Deathrate: 16

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'Agriculture', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['Agriculture'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['Agriculture'],25),np.percentile(df['Agriculture'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['Agriculture'] if i < lower or i > upper]
print('{} Total Number of outliers in Agriculture: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-35-8b936db5aef3>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Agriculture'],  ax=axes[0])
#  Total Number of outliers in Agriculture: 7

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'Industry', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['Industry'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['Industry'],25),np.percentile(df['Industry'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['Industry'] if i < lower or i > upper]
print('{} Total Number of outliers in Industry: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-36-a0401b2741ed>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Industry'],  ax=axes[0])
#  Total Number of outliers in Industry: 12

# %%
f, axes = plt.subplots(1, 2, figsize=(17,7))
sns.boxplot(x = 'Service', data=df,  orient='h' , ax=axes[1])
sns.distplot(df['Service'],  ax=axes[0])
axes[0].set_title('Distribution plot')
axes[1].set_title('Box plot')
plt.show()
#checking count of outliers.
q25,q75=np.percentile(df['Service'],25),np.percentile(df['Service'],75)
IQR=q75-q25
Threshold=IQR*1.5
lower,upper=q25-Threshold,q75+Threshold
Outliers=[i for i in df['Service'] if i < lower or i > upper]
print('{} Total Number of outliers in Industry: {}'.format('\033[1m',len(Outliers)))
# Out:
# <ipython-input-37-ad62db020974>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Service'],  ax=axes[0])
#  Total Number of outliers in Industry: 1

# %% [markdown]
# ### RFE for Feature Selection Process

# %%
from sklearn.model_selection import train_test_split
#X = df.loc[:, [ 'Population','Area','Pop_Density','Coastline','Net_migration','Infant_mortality',
 # 'Literacy','Phones','Arable','Crops','Other','Climate','Birthrate','Deathrate','Agriculture','Industry',
 # 'Service']]
X=df.loc[:,['Population', 'Area (sq. mi.)',
'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)','Net migration', 'Infant mortality (per 1000 births)',
'Literacy (%)', 'Phones (per 1000)', 'Arable (%)', 'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate','Agriculture', 'Industry', 'Service']]
y = df['GDP ($ per capita)']

# %%
# np.isnan(X.any()) #and gets False
# np.isfinite(X.all()) #and gets True

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.ensemble import RandomForestClassifier
regressor = RandomForestClassifier(n_estimators=10, max_depth=10)

from sklearn.feature_selection import RFE
#here we want only one final feature, we do this to produce a ranking
n_features_to_select =7
rfe = RFE(regressor, n_features_to_select=n_features_to_select)
# Fit to the training data
rfe.fit(X_train, y_train)

from operator import itemgetter
features = X_train.columns.to_list()
for x, y in (sorted(zip(rfe.ranking_ , features), key=itemgetter(0))):
   print(x, y)
# Out:
# 1 Area (sq. mi.)
# 1 Pop. Density (per sq. mi.)
# 1 Infant mortality (per 1000 births)
# 1 Phones (per 1000)
# 1 Arable (%)
# 1 Birthrate
# 1 Industry
# 2 Literacy (%)
# 3 Deathrate
# 4 Net migration
# 5 Agriculture
# 6 Other (%)
# 7 Population
# 8 Service
# 9 Coastline (coast/area ratio)
# 10 Crops (%)
# 11 Climate

# %%
sns
# Out:
# <module 'seaborn' from '/usr/local/lib/python3.10/dist-packages/seaborn/__init__.py'>

# %%
#X = df.loc[:, ['Area','Net_migration','Phones','Crops','Birthrate','Agriculture','Industry']]
X=df.loc[:,['Population','Net migration','Infant mortality (per 1000 births)','Phones (per 1000)','Birthrate','Agriculture','Industry']]
X
# Out:
#      Population  Net migration  Infant mortality (per 1000 births)  \
# 0      31056997          23.06                              163.07
# 1       3581655          -4.93                               21.52
# 2      32930091          -0.39                               31.00
# 3         57794         -20.71                                9.27
# 4         71201           6.60                                4.05
# ..          ...            ...                                 ...
# 220      108605          -8.94                                8.03
# 222     2460492           2.98                               19.62
# 224    21456188           0.00                               61.50
# 225    11502010           0.00                               88.29
# 226    12236805           0.00                               67.69
#
#      Phones (per 1000)  Birthrate  Agriculture  Industry
# 0                  3.2      46.60     0.380000  0.240000
# ...

# %%
#Testing for Multicollinearity with Variance Inflation Factors:
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_info = pd.DataFrame()
#calculating VIF for each columns
vif_info['VIF'] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
vif_info['Column'] = X.columns
vif_info.sort_values('VIF', ascending=False)
# Out:
#          VIF                              Column
# 4  12.890129                           Birthrate
# 2   8.095250  Infant mortality (per 1000 births)
# 5   4.929139                         Agriculture
# 6   4.300208                            Industry
# 3   2.160652                   Phones (per 1000)
# 1   1.087040                       Net migration
# 0   1.083845                          Population

# %% [markdown]
# ### Outlier Analysis
# ### We are imputing outiers with mean

# %%
col=['Population','Phones (per 1000)','Industry','Agriculture','Net migration','Infant mortality (per 1000 births)']

# %%
for c in col:
    #getting upper lower quartile values
    q25,q75=np.percentile(df[c],25),np.percentile(df[c],75)
    IQR=q75-q25
    Threshold=IQR*1.5
    lower,upper=q25-Threshold,q75+Threshold
    Outliers=[i for i in df[c] if i < lower or i > upper]
    print('{} Total Number of outliers in {} Before Imputing : {}'.format('\033[1m',c,len(Outliers)))
    print('\n')
    #taking mean of a column without considering outliers
    df_include = df.loc[(df[c] >= lower) & (df[c] <= upper)]
    mean=int(df_include[c].mean())
    print('{} Mean of {} is {}'.format('\033[1m',c,mean))
    print('\n')
    #imputing outliers with mean
    df[c]=np.where(df[c]>upper,mean,df[c])
    df[c]=np.where(df[c]<lower,mean,df[c])
    Outliers=[i for i in df[c] if i < lower or i > upper]
    print('{} Total Number of outliers in {} After Imputing : {}'.format('\033[1m',c,len(Outliers)))
    print('\n')
# Out:
#  Total Number of outliers in Population Before Imputing : 26
#
#
#  Mean of Population is 8068571
#
#
#  Total Number of outliers in Population After Imputing : 0
#
#
#  Total Number of outliers in Phones (per 1000) Before Imputing : 1
#
#
#  Mean of Phones (per 1000) is 230
#
#
#  Total Number of outliers in Phones (per 1000) After Imputing : 0
#
#
#  Total Number of outliers in Industry Before Imputing : 12
#
#
#  Mean of Industry is 0
#
#
#  Total Number of outliers in Industry After Imputing : 0
#
#
#  Total Number of outliers in Agriculture Before Imputing : 7
#
#
#  Mean of Agriculture is 0
#
#
#  Total Number of outliers in Agriculture After Imputing : 0
#
#
#  Total Number of outliers in Net migration Before Imputing : 49
#
#
#  Mean of Net migration is 0
#
#
#  Total Number of outliers in Net migration After Imputing : 0
#
#
#  Total Number of outliers in Infant mortality (per 1000 births) Before Imputing : 5
#
#
#  Mean of Infant mortality (per 1000 births) is 33
#
#
# ...

# %%
#X=df.drop(['GDP','Country','Region'], axis=1)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %% [markdown]
# ### Train-Test Split:

# %%
y=df['GDP ($ per capita)'] #target

# %%
X=df.loc[:,['Population','Phones (per 1000)','Industry','Agriculture','Net migration','Infant mortality (per 1000 births)']]

# %%
# Split X and y into training and test set in 70:30 ratio
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=10)

# %%
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#X_train = scaler.fit_transform(X_train)
#X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
#assign the model
lin = LinearRegression()
#fit the model
lin.fit(X_train, y_train)
#make predictions
lin_pred = lin.predict(X_test)
# evaluate predictions
print('Accuracy on Training data:',lin.score(X_train, y_train) )
print('Accuracy on Test data:',lin.score(X_test, y_test) )
# Out:
# Accuracy on Training data: 0.7695780799731684
# Accuracy on Test data: 0.6151559850780015

# %% [markdown]
# ### Non-Linear model

# %%
X = df.loc[:, ['Population','Phones (per 1000)','Industry','Agriculture','Net migration','Infant mortality (per 1000 births)']]

# %%
y=df['GDP ($ per capita)'] #target

# %%
from sklearn.metrics import r2_score
#from sklearn.metrics import accuracy_score

# %%
from sklearn.ensemble import RandomForestRegressor
model_rf = RandomForestRegressor(n_estimators=100, oob_score=True, random_state=40)
model_rf.fit(X_train, y_train)
pred_train_rf= model_rf.predict(X_train)
print('Accuracy on Training data:',r2_score(y_train, pred_train_rf))
pred_test_rf = model_rf.predict(X_test)
print('Accuracy on Training data:',r2_score(y_test, pred_test_rf))
# Out:
# Accuracy on Training data: 0.9699913229946447
# Accuracy on Training data: 0.716347931039255
